# %%
import pymysql 
import sqlalchemy
from sqlalchemy import create_engine 
import pandas as pd

# %%
import getpass 
password= getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:mypassword' + '@localhost/harry'
engine= create_engine(connection_string)

# %%
df= pd.read_sql_query('Select * from spells', engine )

# %%
df
# Out:
#      spells_id                               Name         Incantation  \
# 0            0                    Summoning Charm               Accio
# 1            1                           Age Line             Unknown
# 2            2                 Water-Making Spell           Aguamenti
# 3            3   Launch an object up into the air    Alarte Ascendare
# 4            4  Albus Dumbledore's Forceful Spell             Unknown
# ..         ...                                ...                 ...
# 296        296                          Waddiwasi           Waddiwasi
# 297        297                   Washing up spell             Unknown
# 298        298                   Levitation Charm  Wingardium Leviosa
# 299        299                       White sparks             Unknown
# 300        300                            Episkey             Episkey
#
#                      Type                                             Effect  \
# 0                   Charm                                  Summons an object
# 1                   Charm  Prevents people above or below a certain age f...
# 2      Charm, Conjuration                                     Conjures water
# 3                   Charm                              Rockets target upward
# 4                   Spell                                        Great Force
# ..                    ...                                                ...
# 296                  Jinx                          Propels wad at the target
# 297                 Charm                                      Cleans dishes
# 298                 Charm                                  Makes objects fly
# 299                 Charm                                Jet of white sparks
# 300  Healing spell, Charm                               Heals minor injuries
#
#         Light
# 0        None
# 1        Blue
# 2    Icy blue
# 3         Red
# 4        None
# ..        ...
# 296      None
# 297      None
# 298      None
# 299     White
# 300      None
#
# [301 rows x 6 columns]

# %%
df.Type.value_counts()
# Out:
# Charm                                148
# Jinx                                  29
# Curse                                 26
# Transfiguration                       21
# Hex                                   19
# Spell                                 11
# Conjuration                            9
# Charm                                  4
# Dark Arts                              3
# Healing spell, Charm                   3
# Counter-charm                          2
# Transfiguration Jinx                   2
# Dark charm                             2
# Counter-spell                          1
# Transportation                         1
# Transfiguration, Jinx                  1
# Healing spell, Vanishment              1
# Conjuration, Charm                     1
# Curse, Jinx                            1
# Hex, Counter-curse                     1
# Transformation                         1
# Healing spell, Counter-curse           1
# Jinx, Hex                              1
# Conjuration, Jinx                      1
# Patented Charm                         1
# Transfiguration spell                  1
# Counter-jinx                           1
# Vanishment                             1
# Transfiguration jinx                   1
# Charm, Counter-charm                   1
# Charm, Transfiguration                 1
# Hex                                    1
# Healing Spell, Charm, Conjuration      1
# Untransfiguration                      1
# Charm, Conjuration                     1
# Name: Type, dtype: int64
